# %% [markdown]
# # 2.1 图像的基本表示方法

# %% [markdown]
# **图像的表现方式有三种：**二值图像、灰度图像、彩色图像。
# 不同的表现方式，像素的取值范围不同。
# 1. 二值图像：取值范围[0,1]，只包含了黑色和白色两种。
# ![Binary_image01.jpeg](../images/Binary_image01.jpeg)

# %% [markdown]
# **二值图像的矩阵形式如下：**![Binary_image02.jpeg](../images/Binary_image02.jpeg)

# %% [markdown]
# 2. **灰度图像**: 取值范围[0,255]
# ![Lena_gray_image.jpeg](attachment:Lena_gray_image.jpeg)

# %% [markdown]
# **灰度值的对应二进制和十进制**
# ![gray_image_level.jpeg](attachment:gray_image_level.jpeg)

# %% [markdown]
# **Lena灰度图一部分像素数值：**
# ![lena_gray_imageValue.jpeg](attachment:lena_gray_imageValue.jpeg)

# %% [markdown]
# 3. 彩色图像：取值范围[0,255]，但是彩色图像有色光的三个原色，红、绿、蓝。RGB色彩空间，由三个通道组成。三种颜色共同组成了每个图像某一个像素位置的值。一般情况下：RGB色彩空间中，图像的顺序是R-G-B，**但是在OpenCV处理的时候，通道顺序是B-G-R。**

# %% [markdown]
# # 2.2 像素处理

# %%
import cv2 as cv
import numpy as np

img = np.zeros((8, 8), dtype=np.uint8)  # Using numpy zeros to create an array
print("img=\n", img)
cv.imshow("one", img)
print("读取像素点", img[0, 3])
img[0, 3] = 255     # change a pixel value in a images
print("img=\n", img)
print("修改之后的像素点", img[0, 3])
cv.imshow("two", img)
cv.waitKey()
cv.destroyAllWindows()
